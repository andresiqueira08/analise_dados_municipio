# %%
import pandas as pd

# %%
with open("../data/microdados_ed_basica_2024.csv", "r") as f:
    conteudo = f.read()

# %%
#O governo utiliza de ";" para separar os dados no csv.
df = pd.read_csv("../data/microdados_ed_basica_2024.csv", encoding="latin-1", sep=";")
# Out:
# C:\Users\LORENA\AppData\Local\Temp\ipykernel_15464\2885232389.py:1: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/microdados_ed_basica_2024.csv", encoding="latin-1", sep=";")

# %%
#Definindo municipio e variáveis propostas para análise.
df_reduzido = df[df['NO_MUNICIPIO'] == 'Surubim'][[
    'NU_ANO_CENSO',
    'TP_DEPENDENCIA',
    'TP_LOCALIZACAO',
    'TP_SITUACAO_FUNCIONAMENTO',
    'IN_AGUA_REDE_PUBLICA',
    'IN_AUDITORIO',
    'IN_BIBLIOTECA',
    'IN_LABORATORIO_INFORMATICA',
    'IN_QUADRA_ESPORTES',
    'IN_LABORATORIO_CIENCIAS',
    'QT_MAT_BAS'
]]
# Out:
#        NU_ANO_CENSO  TP_DEPENDENCIA  TP_LOCALIZACAO  \
# 74096          2024               4               1
# 74097          2024               4               1
# 74098          2024               3               1
# 74099          2024               2               1
# 74100          2024               2               1
# ...             ...             ...             ...
# 74160          2024               4               1
# 74161          2024               4               1
# 74162          2024               2               1
# 74163          2024               3               1
# 74164          2024               3               2
#
#        TP_SITUACAO_FUNCIONAMENTO  IN_AGUA_REDE_PUBLICA  IN_AUDITORIO  \
# 74096                          1                   1.0           0.0
# 74097                          1                   1.0           1.0
# 74098                          1                   1.0           0.0
# ...

# %%
#Salva o novo dataframe em csv
df_reduzido.to_csv('../data/df_reduzido.csv', index=False)
